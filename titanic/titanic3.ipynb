# %% [markdown]
# # Model Building & Evaluation

# %% [markdown]
# Now that we've processed the data and produced a clean numeric-only set for training, we can train multiple classification models using sklearn. Specifically, we'll test:
#
# 1. Logistic Regression
# 2. Decision Tree
# 3. Random Forest
# 4. K-Nearest Neighbors (KNN)
# 5. Support Vector Machine (SVM)
# 6. Gradient Boosting
# 7. Naive Bayes

# %% [markdown]
# We'll start by importing all the relevant libraries.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from clean_data import clean

from sklearn.pipeline import Pipeline
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import GridSearchCV, cross_validate

# %% [markdown]
# Let's start with running a basic Logistic Regression model. First, let's verify the clean data function on the test dataset.

# %%
df = pd.read_csv("titanic_cleaned.csv")
test = pd.read_csv("test.csv")

processed_test = clean(test)

processed_test.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Pclass                418 non-null    int64
#  1   Sex                   418 non-null    int64
#  2   Age                   418 non-null    float64
#  3   SibSp                 418 non-null    int64
#  4   Parch                 418 non-null    int64
#  5   Fare                  418 non-null    float64
#  6   HasCabin              418 non-null    int64
#  7   FamilySize            418 non-null    int64
#  8   IsAlone               418 non-null    int64
#  9   Embarked_Q            418 non-null    int64
#  10  Embarked_S            418 non-null    int64
#  11  Title_Miss            418 non-null    int64
#  12  Title_Mr              418 non-null    int64
#  13  Title_Mrs             418 non-null    int64
#  14  Title_Rare            418 non-null    int64
# ...

# %%
y = df["Survived"]
X = df.drop(columns = ["Survived"])

pipe = Pipeline([
    ('scaler', StandardScaler()),
    ('model', LogisticRegression(C=.5, verbose=1))
])


"""
val = cross_validate(pipe, X, y)
np.mean(val['test_score'])
"""

pipe2 = Pipeline([
    ('scaler', StandardScaler),
    ('model', DecisionTreeClassifier(random_state=42))
])
